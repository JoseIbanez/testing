# %% [markdown]
# ![iceberg-logo](https://www.apache.org/logos/res/iceberg/iceberg.png)

# %% [markdown]
# ### [Integrated Audits: Streamlined Data Observability with Apache Iceberg](https://tabular.io/blog/integrated-audits/)

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Jupyter").getOrCreate()

spark
# Out:
# 25/07/02 17:13:05 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://08d03577c43b:4045">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.5</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# To be able to rerun the notebook several times, let's drop the `permits` table if it exists to start fresh.

# %%
# %%sql
#
# CREATE DATABASE IF NOT EXISTS nyc
# Out:
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# DROP TABLE IF EXISTS nyc.permits
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# # Load NYC Film Permits Data

# %% [markdown]
# For this demo, we will use the [New York City Film Permits dataset](https://data.cityofnewyork.us/City-Government/Film-Permits/tg4x-b46p) available as part of the NYC Open Data initiative. We're using a locally saved copy of a 1000 record sample, but feel free to download the entire dataset to use in this notebook!
#
# We'll save the sample dataset into an iceberg table called `permits`.

# %%
df = spark.read.option("inferSchema","true").option("multiline","true").json("/home/iceberg/data/nyc_film_permits.json")
df.write.saveAsTable("nyc.permits")

# %%
df1 = spark.read.option("inferSchema","true").option("multiline","false").json("/home/iceberg/warehouse/esm.jsonl")

from pyspark.sql import functions as F

# %%
df1.printSchema()


df1.select(df1._source.customer, 
           df1._source.source.id.alias('source_id'),
           df1._source.metric.value.alias('metric_value'),
           df1._source.metric['name'].alias('metric_name'),
          ).printSchema()
# Out:
# root
#  |-- _id: string (nullable = true)
#  |-- _index: string (nullable = true)
#  |-- _score: long (nullable = true)
#  |-- _source: struct (nullable = true)
#  |    |-- @timestamp: string (nullable = true)
#  |    |-- @version: string (nullable = true)
#  |    |-- collectorId: string (nullable = true)
#  |    |-- customer: string (nullable = true)
#  |    |-- domain: string (nullable = true)
#  |    |-- environment: string (nullable = true)
#  |    |-- eventId: string (nullable = true)
#  |    |-- eventTime: string (nullable = true)
#  |    |-- eventType: string (nullable = true)
#  |    |-- metric: struct (nullable = true)
#  |    |    |-- labels: struct (nullable = true)
#  |    |    |    |-- __name__: string (nullable = true)
#  |    |    |    |-- job: string (nullable = true)
#  |    |    |    |-- kpi_uid: string (nullable = true)
#  |    |    |    |-- metricPeriod: string (nullable = true)
#  |    |    |    |-- modelUid: string (nullable = true)
#  |    |    |    |-- storage_type: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- value: long (nullable = true)
#  |    |-- opCo: string (nullable = true)
#  |    |-- product: string (nullable = true)
#  |    |-- raw: string (nullable = true)
#  |    |-- schemaVersion: string (nullable = true)
#  |    |-- source: struct (nullable = true)
#  |    |    |-- extId: string (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- labels: struct (nullable = true)
#  |    |    |    |-- bucket_name: string (nullable = true)
#  |    |-- timeReceived: string (nullable = true)
#  |    |-- timestamp: long (nullable = true)
#
# root
#  |-- _source.customer: string (nullable = true)
#  |-- source_id: string (nullable = true)
#  |-- metric_value: long (nullable = true)
#  |-- metric_name: string (nullable = true)

# %%
df = spark.read.parquet("s3a://ingress/yellow_tripdata_2022-02.parquet");
df.count()
#df.show()
# Out:
# 2979431

# %%
df1 = spark.read.option("inferSchema","true").option("multiline","false").json("s3a://ingress/cisco-vmanage-pm-metrics_data.jsonl.gz")
df1.printSchema()
# Out:
# [Stage 1:>                                                          (0 + 1) / 1]
# root
#  |-- _id: string (nullable = true)
#  |-- _index: string (nullable = true)
#  |-- _score: long (nullable = true)
#  |-- _source: struct (nullable = true)
#  |    |-- @timestamp: string (nullable = true)
#  |    |-- @version: string (nullable = true)
#  |    |-- collectorId: string (nullable = true)
#  |    |-- customer: string (nullable = true)
#  |    |-- domain: string (nullable = true)
#  |    |-- environment: string (nullable = true)
#  |    |-- eventId: string (nullable = true)
#  |    |-- eventTime: string (nullable = true)
#  |    |-- eventType: string (nullable = true)
#  |    |-- metric: struct (nullable = true)
#  |    |    |-- labels: struct (nullable = true)
#  |    |    |    |-- admin_status: string (nullable = true)
#  |    |    |    |-- af_type: string (nullable = true)
#  |    |    |    |-- app_probe_class: string (nullable = true)
#  |    |    |    |-- bw_down: long (nullable = true)
#  |    |    |    |-- bw_up: long (nullable = true)
#  |    |    |    |-- device_model: string (nullable = true)
#  |    |    |    |-- dst_ip: string (nullable = true)
#  |    |    |    |-- dst_port: long (nullable = true)
#  |    |    |    |-- host_name: string (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- interface: string (nullable = true)
#  |    |    |    |-- interface_type: string (nullable = true)
#  |    |    |    |-- local_color: string (nullable = true)
#  |    |    |    |-- local_system_ip: string (nullable = true)
#  |    |    |    |-- mem_util: double (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- oper_status: string (nullable = true)
#  |    |    |    |-- proto: string (nullable = true)
#  |    |    |    |-- remote_color: string (nullable = true)
#  |    |    |    |-- remote_system_ip: string (nullable = true)
#  |    |    |    |-- sla_class_list: string (nullable = true)
#  |    |    |    |-- src_ip: string (nullable = true)
#  |    |    |    |-- src_port: long (nullable = true)
#  |    |    |    |-- state: string (nullable = true)
#  |    |    |    |-- tenant: string (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- tunnel_color: string (nullable = true)
#  |    |    |    |-- vdevice_name: string (nullable = true)
#  |    |    |    |-- vip_idx: long (nullable = true)
#  |    |    |    |-- vmanage_system_ip: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- value: double (nullable = true)
#  |    |-- opCo: string (nullable = true)
#  |    |-- product: string (nullable = true)
#  |    |-- raw: string (nullable = true)
#  |    |-- sensitivity: long (nullable = true)
#  |    |-- source: struct (nullable = true)
#  |    |    |-- extId: string (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |-- timeReceived: string (nullable = true)
#  |    |-- timestamp: long (nullable = true)

# %%
from pyspark.sql.types import StructType, StructField, StringType, DoubleType, TimestampType, TimestampNTZType, MapType

schema = StructType([
    StructField("_source",StructType([
        StructField("customer",StringType()),
        StructField("eventId",StringType()),
        StructField("eventTime",TimestampType()),
        StructField("timeReceived",TimestampType()),        
        StructField("domain",StringType()),
        StructField("source",StructType([
            StructField("id",StringType()),
            StructField("labels",MapType(StringType(),StringType()))
            ])),
        StructField("metric",StructType([
            StructField("name",StringType()),
            StructField("value",DoubleType()),
            StructField("labels",MapType(StringType(),StringType()))
            ]))
        ]))
    ])

# %%
# %%sql
#
# DROP TABLE IF EXISTS nyc.esm_metric;
# Out:
# ++
# ||
# ++
# ++

# %%
#df2 = spark.read.schema(schema).json("/home/iceberg/warehouse/esm-mpn-logstash-oss-performance_data.jsonl.gz")
#df2 = spark.read.schema(schema).json("/home/iceberg/datahouse/vf/cisco-vmanage-pm-metrics_20250601a.jsonl.gz")
#df2 = spark.read.schema(schema).json("/home/iceberg/datahouse/vf/cisco-vmanage-pm-metrics_20250601b.jsonl.gz")

#df2 = spark.read.schema(schema).json("s3a://ingress/cisco-vmanage-pm-metrics_20250601a.jsonl.gz");
#df2 = spark.read.schema(schema).json("s3a://ingress/cisco-vmanage-pm-metrics_20250601b.jsonl.gz");
df2 = spark.read.schema(schema).json("s3a://ingress/cisco-vmanage-pm-metrics_20250602a.jsonl.gz");



df3 = df2.select(df2._source.customer.alias("customer"), 
           df2._source.eventId.alias("eventId"),
           df2._source.eventTime.alias("eventTime"),           
           df2._source.timeReceived.alias("timeReceived"),
           df2._source.source.id.alias("source_id"),
           df2._source.source.labels.alias("source_labels"),
           df2._source.metric["name"].alias("metric_name"),
           df2._source.metric.value.alias("metric_value"),
           df2._source.metric.labels.alias("metric_labels")
          )

df3.count()
df3.head()
#df3.write.saveAsTable("nyc.esm_metric")
df3.write.insertInto("nyc.esm_metric")

#df3.coalesce(1).write.save("/tmp/nyc.esm_metric_01")

# %%
# %%sql
#
# DESCRIBE TABLE nyc.esm_metric;
# Out:
# +---------------+--------------------+---------+
# |      col_name |          data_type | comment |
# +---------------+--------------------+---------+
# |      customer |             string |    None |
# |       eventId |             string |    None |
# |     eventTime |          timestamp |    None |
# |  timeReceived |          timestamp |    None |
# |     source_id |             string |    None |
# | source_labels | map<string,string> |    None |
# |   metric_name |             string |    None |
# |  metric_value |             double |    None |
# | metric_labels | map<string,string> |    None |
# +---------------+--------------------+---------+

# %%
# %%sql
#
# SELECT customer, eventTime, source_id, metric_name, metric_value FROM nyc.esm_metric LIMIT 100;
# Out:
# +----------+----------------------------+---------------------------------------------------------------------------------+-----------------+--------------+
# | customer |                  eventTime |                                                                       source_id |     metric_name | metric_value |
# +----------+----------------------------+---------------------------------------------------------------------------------+-----------------+--------------+
# |      anz | 2025-06-01 00:16:51.962000 |                    anz/VF1358-5012/appRoute/10.245.10.22:mpls-10.245.10.64:mpls |       tx_octets |          0.0 |
# |      anz | 2025-06-01 00:16:51.962000 |                    anz/VF1358-5012/appRoute/10.245.10.22:mpls-10.245.10.64:mpls |       rx_octets |          0.0 |
# |      anz | 2025-05-31 23:42:20.607000 |            anz/VF1358-5059/appRoute/10.245.10.69:private1-10.245.10.13:private1 |      vqoe_score |          7.0 |
# |      anz | 2025-05-31 23:42:20.607000 |            anz/VF1358-5059/appRoute/10.245.10.69:private1-10.245.10.13:private1 |       rx_octets |     108643.0 |
# |      anz | 2025-05-31 23:42:20.607000 |            anz/VF1358-5059/appRoute/10.245.10.69:private1-10.245.10.13:private1 | loss_percentage |          0.0 |
# |      anz | 2025-05-31 23:48:22.117000 | anz/VF1358-5026/appRoute/10.245.10.36:biz-internet-10.245.10.12:public-internet |      vqoe_score |          8.0 |
# |      anz | 2025-05-31 23:48:22.117000 | anz/VF1358-5026/appRoute/10.245.10.36:biz-internet-10.245.10.12:public-internet |            loss |          0.0 |
# |      anz | 2025-05-31 23:48:22.117000 | anz/VF1358-5026/appRoute/10.245.10.36:biz-internet-10.245.10.12:public-internet |         rx_pkts |        133.0 |
# |      anz | 2025-05-31 23:48:22.117000 | anz/VF1358-5026/appRoute/10.245.10.36:biz-internet-10.245.10.12:public-internet |          jitter |          0.0 |
# |      anz | 2025-06-01 00:16:52.845000 | anz/VF1358-5012/appRoute/10.245.10.22:public-internet-10.245.10.26:biz-internet |       tx_octets |          0.0 |
# |      anz | 2025-05-31 23:46:25.305000 |    anz/VF1358-5069/appRoute/10.245.10.79:biz-internet-10.245.10.26:biz-internet |           state |        100.0 |
# |      anz | 2025-05-31 23:46:25.305000 |    anz/VF1358-5069/appRoute/10.245.10.79:biz-internet-10.245.10.26:biz-internet |      vqoe_score |          8.0 |
# |      anz | 2025-05-31 23:46:25.305000 |    anz/VF1358-5069/appRoute/10.245.10.79:biz-internet-10.245.10.26:biz-internet |           total |        132.0 |
# |      anz | 2025-05-31 23:46:25.305000 |    anz/VF1358-5069/appRoute/10.245.10.79:biz-internet-10.245.10.26:biz-internet |         tx_pkts |          0.0 |
# |      anz | 2025-05-31 23:46:25.305000 |    anz/VF1358-5069/appRoute/10.245.10.79:biz-internet-10.245.10.26:biz-internet |       rx_octets |          0.0 |
# |      anz | 2025-05-31 23:46:25.305000 |    anz/VF1358-5069/appRoute/10.245.10.79:biz-internet-10.245.10.26:biz-internet |          jitter |          0.0 |
# |      anz | 2025-05-31 23:39:26.564000 |    anz/VF1358-5046/appRoute/10.245.10.56:biz-internet-10.245.10.20:biz-internet |            loss |          1.0 |
# |      anz | 2025-05-31 23:39:26.564000 |    anz/VF1358-5046/appRoute/10.245.10.56:biz-internet-10.245.10.20:biz-internet |           total |        129.0 |
# |      anz | 2025-06-01 00:16:51.962000 |                    anz/VF1358-5012/appRoute/10.245.10.22:mpls-10.245.10.64:mpls |           state |        100.0 |
# |      anz | 2025-06-01 00:16:51.962000 |                    anz/VF1358-5012/appRoute/10.245.10.22:mpls-10.245.10.64:mpls |           total |        129.0 |
# |      anz | 2025-05-31 23:42:20.607000 |            anz/VF1358-5059/appRoute/10.245.10.69:private1-10.245.10.13:private1 |         latency |        134.0 |
# |      anz | 2025-05-31 23:42:20.607000 |            anz/VF1358-5059/appRoute/10.245.10.69:private1-10.245.10.13:private1 |       tx_octets |      54849.0 |
# |      anz | 2025-05-31 23:42:20.607000 |            anz/VF1358-5059/appRoute/10.245.10.69:private1-10.245.10.13:private1 |            loss |          0.0 |
# |      anz | 2025-05-31 23:42:20.607000 |            anz/VF1358-5059/appRoute/10.245.10.69:private1-10.245.10.13:private1 |           total |        128.0 |
# |      anz | 2025-05-31 23:39:26.564000 |    anz/VF1358-5046/appRoute/10.245.10.56:biz-internet-10.245.10.20:biz-internet | loss_percentage |        0.775 |
# |      anz | 2025-06-01 00:16:52.847000 | anz/VF1358-5012/appRoute/10.245.10.22:public-internet-10.245.10.19:biz-internet |       rx_octets |          0.0 |
# |      anz | 2025-06-01 00:16:52.847000 | anz/VF1358-5012/appRoute/10.245.10.22:public-internet-10.245.10.19:biz-internet |           state |        100.0 |
# |      anz | 2025-06-01 00:16:52.847000 | anz/VF1358-5012/appRoute/10.245.10.22:public-internet-10.245.10.19:biz-internet |         latency |         63.0 |
# |      anz | 2025-06-01 00:16:52.847000 | anz/VF1358-5012/appRoute/10.245.10.22:public-internet-10.245.10.19:biz-internet |       tx_octets |          0.0 |
# |      anz | 2025-06-01 00:16:52.847000 | anz/VF1358-5012/appRoute/10.245.10.22:public-internet-10.245.10.19:biz-internet |          jitter |         13.0 |
# |      anz | 2025-06-01 00:16:51.962000 |                    anz/VF1358-5012/appRoute/10.245.10.22:mpls-10.245.10.64:mpls |      vqoe_score |          7.0 |
# |      anz | 2025-06-01 00:16:51.962000 |                    anz/VF1358-5012/appRoute/10.245.10.22:mpls-10.245.10.64:mpls |         latency |        118.0 |
# |      anz | 2025-06-01 00:16:51.962000 |                    anz/VF1358-5012/appRoute/10.245.10.22:mpls-10.245.10.64:mpls |            loss |          0.0 |
# |      anz | 2025-06-01 00:16:51.962000 |                    anz/VF1358-5012/appRoute/10.245.10.22:mpls-10.245.10.64:mpls |         tx_pkts |          0.0 |
# |      anz | 2025-06-01 00:16:51.962000 |                    anz/VF1358-5012/appRoute/10.245.10.22:mpls-10.245.10.64:mpls | loss_percentage |          0.0 |
# |      anz | 2025-06-01 00:16:51.962000 |                    anz/VF1358-5012/appRoute/10.245.10.22:mpls-10.245.10.64:mpls |         rx_pkts |          0.0 |
# |      anz | 2025-06-01 00:16:51.962000 |                    anz/VF1358-5012/appRoute/10.245.10.22:mpls-10.245.10.64:mpls |          jitter |          0.0 |
# |      anz | 2025-05-31 23:42:20.607000 |            anz/VF1358-5059/appRoute/10.245.10.69:private1-10.245.10.13:private1 |          jitter |          0.0 |
# |      anz | 2025-05-31 23:48:22.117000 | anz/VF1358-5026/appRoute/10.245.10.36:biz-internet-10.245.10.12:public-internet | loss_percentage |          0.0 |
# |      anz | 2025-06-01 00:16:52.845000 | anz/VF1358-5012/appRoute/10.245.10.22:public-internet-10.245.10.26:biz-internet |      vqoe_score |         10.0 |
# |      anz | 2025-06-01 00:16:52.845000 | anz/VF1358-5012/appRoute/10.245.10.22:public-internet-10.245.10.26:biz-internet |         latency |         51.0 |
# |      anz | 2025-06-01 00:16:52.845000 | anz/VF1358-5012/appRoute/10.245.10.22:public-internet-10.245.10.26:biz-internet |            loss |          0.0 |
# |      anz | 2025-06-01 00:16:52.845000 | anz/VF1358-5012/appRoute/10.245.10.22:public-internet-10.245.10.26:biz-internet |           total |        128.0 |
# |      anz | 2025-05-31 23:42:20.607000 |            anz/VF1358-5059/appRoute/10.245.10.69:private1-10.245.10.13:private1 |           state |        100.0 |
# |      anz | 2025-05-31 23:42:20.607000 |            anz/VF1358-5059/appRoute/10.245.10.69:private1-10.245.10.13:private1 |         tx_pkts |        300.0 |
# |      anz | 2025-05-31 23:42:20.607000 |            anz/VF1358-5059/appRoute/10.245.10.69:private1-10.245.10.13:private1 |         rx_pkts |        414.0 |
# |      anz | 2025-05-31 23:46:25.309000 | anz/VF1358-5069/appRoute/10.245.10.79:biz-internet-10.245.10.11:public-internet |         latency |        194.0 |
# |      anz | 2025-05-31 23:46:25.309000 | anz/VF1358-5069/appRoute/10.245.10.79:biz-internet-10.245.10.11:public-internet |         tx_pkts |       1018.0 |
# |      anz | 2025-05-31 23:46:25.309000 | anz/VF1358-5069/appRoute/10.245.10.79:biz-internet-10.245.10.11:public-internet |       rx_octets |      10922.0 |
# |      anz | 2025-05-31 23:39:26.565000 |    anz/VF1358-5046/appRoute/10.245.10.56:biz-internet-10.245.10.10:biz-internet |           state |        100.0 |
# |      anz | 2025-05-31 23:39:26.565000 |    anz/VF1358-5046/appRoute/10.245.10.56:biz-internet-10.245.10.10:biz-internet |      vqoe_score |          6.0 |
# |      anz | 2025-05-31 23:39:26.565000 |    anz/VF1358-5046/appRoute/10.245.10.56:biz-internet-10.245.10.10:biz-internet |       tx_octets |       1280.0 |
# |      anz | 2025-05-31 23:48:22.117000 | anz/VF1358-5026/appRoute/10.245.10.36:biz-internet-10.245.10.12:public-internet |           state |        100.0 |
# |      anz | 2025-05-31 23:48:22.117000 | anz/VF1358-5026/appRoute/10.245.10.36:biz-internet-10.245.10.12:public-internet |         latency |         83.0 |
# |      anz | 2025-05-31 23:48:22.117000 | anz/VF1358-5026/appRoute/10.245.10.36:biz-internet-10.245.10.12:public-internet |       tx_octets |      65649.0 |
# |      anz | 2025-05-31 23:46:25.305000 |    anz/VF1358-5069/appRoute/10.245.10.79:biz-internet-10.245.10.26:biz-internet |       tx_octets |          0.0 |
# |      anz | 2025-05-31 23:46:25.305000 |    anz/VF1358-5069/appRoute/10.245.10.79:biz-internet-10.245.10.26:biz-internet |            loss |          0.0 |
# |      anz | 2025-05-31 23:46:25.305000 |    anz/VF1358-5069/appRoute/10.245.10.79:biz-internet-10.245.10.26:biz-internet |         rx_pkts |          0.0 |
# |      anz | 2025-05-31 23:39:26.564000 |    anz/VF1358-5046/appRoute/10.245.10.56:biz-internet-10.245.10.20:biz-internet |      vqoe_score |          3.0 |
# |      anz | 2025-05-31 23:39:26.564000 |    anz/VF1358-5046/appRoute/10.245.10.56:biz-internet-10.245.10.20:biz-internet |       tx_octets |          0.0 |
# |      anz | 2025-05-31 23:39:26.564000 |    anz/VF1358-5046/appRoute/10.245.10.56:biz-internet-10.245.10.20:biz-internet |         tx_pkts |          0.0 |
# |      anz | 2025-05-31 23:48:22.117000 | anz/VF1358-5026/appRoute/10.245.10.36:biz-internet-10.245.10.12:public-internet |           total |        133.0 |
# |      anz | 2025-05-31 23:39:26.565000 |    anz/VF1358-5046/appRoute/10.245.10.56:biz-internet-10.245.10.10:biz-internet |         tx_pkts |         20.0 |
# |      anz | 2025-05-31 23:39:26.565000 |    anz/VF1358-5046/appRoute/10.245.10.56:biz-internet-10.245.10.10:biz-internet |       rx_octets |          0.0 |
# |      anz | 2025-05-31 23:39:26.565000 |    anz/VF1358-5046/appRoute/10.245.10.56:biz-internet-10.245.10.10:biz-internet | loss_percentage |          0.0 |
# |      anz | 2025-05-31 23:39:26.565000 |    anz/VF1358-5046/appRoute/10.245.10.56:biz-internet-10.245.10.10:biz-internet |         rx_pkts |          0.0 |
# |      anz | 2025-05-31 23:39:26.565000 |    anz/VF1358-5046/appRoute/10.245.10.56:biz-internet-10.245.10.10:biz-internet |          jitter |          0.0 |
# |      anz | 2025-06-01 00:16:52.849000 | anz/VF1358-5012/appRoute/10.245.10.22:public-internet-10.245.10.29:biz-internet |           state |        100.0 |
# |      anz | 2025-05-31 23:48:22.117000 | anz/VF1358-5026/appRoute/10.245.10.36:biz-internet-10.245.10.12:public-internet |         tx_pkts |        263.0 |
# |      anz | 2025-05-31 23:48:22.117000 | anz/VF1358-5026/appRoute/10.245.10.36:biz-internet-10.245.10.12:public-internet |       rx_octets |      25493.0 |
# |      anz | 2025-06-01 00:16:52.845000 | anz/VF1358-5012/appRoute/10.245.10.22:public-internet-10.245.10.26:biz-internet |           state |        100.0 |
# |      anz | 2025-06-01 00:16:52.845000 | anz/VF1358-5012/appRoute/10.245.10.22:public-internet-10.245.10.26:biz-internet |         tx_pkts |          0.0 |
# |      anz | 2025-06-01 00:16:52.845000 | anz/VF1358-5012/appRoute/10.245.10.22:public-internet-10.245.10.26:biz-internet |       rx_octets |          0.0 |
# |      anz | 2025-05-31 23:39:26.564000 |    anz/VF1358-5046/appRoute/10.245.10.56:biz-internet-10.245.10.20:biz-internet |       rx_octets |          0.0 |
# |      anz | 2025-06-01 00:16:52.847000 | anz/VF1358-5012/appRoute/10.245.10.22:public-internet-10.245.10.19:biz-internet |      vqoe_score |          9.0 |
# |      anz | 2025-06-01 00:16:52.847000 | anz/VF1358-5012/appRoute/10.245.10.22:public-internet-10.245.10.19:biz-internet |            loss |          0.0 |
# |      anz | 2025-06-01 00:16:52.847000 | anz/VF1358-5012/appRoute/10.245.10.22:public-internet-10.245.10.19:biz-internet |           total |        128.0 |
# |      anz | 2025-06-01 00:16:52.847000 | anz/VF1358-5012/appRoute/10.245.10.22:public-internet-10.245.10.19:biz-internet |         tx_pkts |          0.0 |
# |      anz | 2025-06-01 00:16:52.847000 | anz/VF1358-5012/appRoute/10.245.10.22:public-internet-10.245.10.19:biz-internet | loss_percentage |          0.0 |
# |      anz | 2025-06-01 00:16:52.849000 | anz/VF1358-5012/appRoute/10.245.10.22:public-internet-10.245.10.29:biz-internet |      vqoe_score |          3.0 |
# |      anz | 2025-06-01 00:16:52.849000 | anz/VF1358-5012/appRoute/10.245.10.22:public-internet-10.245.10.29:biz-internet |         tx_pkts |          0.0 |
# |      anz | 2025-05-31 23:46:25.309000 | anz/VF1358-5069/appRoute/10.245.10.79:biz-internet-10.245.10.11:public-internet |           state |        100.0 |
# |      anz | 2025-05-31 23:46:25.309000 | anz/VF1358-5069/appRoute/10.245.10.79:biz-internet-10.245.10.11:public-internet |       tx_octets |    1078876.0 |
# |      anz | 2025-05-31 23:46:25.309000 | anz/VF1358-5069/appRoute/10.245.10.79:biz-internet-10.245.10.11:public-internet |           total |        133.0 |
# |      anz | 2025-05-31 23:46:25.309000 | anz/VF1358-5069/appRoute/10.245.10.79:biz-internet-10.245.10.11:public-internet |         rx_pkts |         29.0 |
# |      anz | 2025-05-31 23:46:25.309000 | anz/VF1358-5069/appRoute/10.245.10.79:biz-internet-10.245.10.11:public-internet |          jitter |          0.0 |
# |      anz | 2025-05-31 23:39:26.565000 |    anz/VF1358-5046/appRoute/10.245.10.56:biz-internet-10.245.10.10:biz-internet |            loss |          0.0 |
# |      anz | 2025-06-01 00:16:52.849000 | anz/VF1358-5012/appRoute/10.245.10.22:public-internet-10.245.10.29:biz-internet | loss_percentage |        0.787 |
# |      anz | 2025-06-01 00:16:52.849000 | anz/VF1358-5012/appRoute/10.245.10.22:public-internet-10.245.10.29:biz-internet |         rx_pkts |          0.0 |
# |      anz | 2025-06-01 00:16:52.849000 | anz/VF1358-5012/appRoute/10.245.10.22:public-internet-10.245.10.29:biz-internet |          jitter |         18.0 |
# |      anz | 2025-06-01 00:08:47.748000 |                anz/VF1358-5056/appRoute/10.245.10.66:mpls-10.245.10.39:private1 |           state |        100.0 |
# |      anz | 2025-06-01 00:16:52.845000 | anz/VF1358-5012/appRoute/10.245.10.22:public-internet-10.245.10.26:biz-internet | loss_percentage |          0.0 |
# |      anz | 2025-06-01 00:16:52.845000 | anz/VF1358-5012/appRoute/10.245.10.22:public-internet-10.245.10.26:biz-internet |         rx_pkts |          0.0 |
# |      anz | 2025-06-01 00:16:52.845000 | anz/VF1358-5012/appRoute/10.245.10.22:public-internet-10.245.10.26:biz-internet |          jitter |         15.0 |
# |      anz | 2025-05-31 23:46:25.305000 |    anz/VF1358-5069/appRoute/10.245.10.79:biz-internet-10.245.10.26:biz-internet |         latency |         83.0 |
# |      anz | 2025-05-31 23:46:25.305000 |    anz/VF1358-5069/appRoute/10.245.10.79:biz-internet-10.245.10.26:biz-internet | loss_percentage |          0.0 |
# |      anz | 2025-05-31 23:39:26.564000 |    anz/VF1358-5046/appRoute/10.245.10.56:biz-internet-10.245.10.20:biz-internet |           state |        100.0 |
# |      anz | 2025-06-01 00:08:47.748000 |                anz/VF1358-5056/appRoute/10.245.10.66:mpls-10.245.10.39:private1 |           total |        128.0 |
# |      anz | 2025-06-01 00:08:47.748000 |                anz/VF1358-5056/appRoute/10.245.10.66:mpls-10.245.10.39:private1 | loss_percentage |          0.0 |
# |      anz | 2025-06-01 00:08:47.748000 |                anz/VF1358-5056/appRoute/10.245.10.66:mpls-10.245.10.39:private1 |         rx_pkts |          0.0 |
# +----------+----------------------------+---------------------------------------------------------------------------------+-----------------+--------------+

# %%
# %%sql
#
# SELECT count(*) FROM nyc.esm_metric;
# Out:
# +----------+
# | count(1) |
# +----------+
# | 44469068 |
# +----------+

# %%
# %%sql
#
# SELECT DISTINCT metric_name FROM nyc.esm_metric;
# Out:
# +--------------------------+
# |              metric_name |
# +--------------------------+
# |          loss_percentage |
# |               total_mbps |
# |                 min5_avg |
# |                 mem_free |
# |                   jitter |
# |                 min1_avg |
# |                disk_used |
# |                rx_octets |
# |                  rx_kbps |
# |                min15_avg |
# |                 cpu_user |
# |                  rx_pkts |
# |                 cpu_idle |
# |                   totalp |
# | down_capacity_percentage |
# |                tx_octets |
# |               mem_cached |
# |                   rx_pps |
# |             cpu_user_new |
# |                 mem_used |
# |                 rx_drops |
# |                  tx_kbps |
# |              oper_status |
# |               vqoe_score |
# |                     loss |
# |                  tx_pkts |
# |   up_capacity_percentage |
# |                tx_errors |
# |                  latency |
# |                    state |
# |               disk_avail |
# |                rx_errors |
# |              mem_buffers |
# |               cpu_system |
# |                    total |
# |            cpu_min15_avg |
# |                 runningp |
# |             cpu_min1_avg |
# |             cpu_min5_avg |
# |                   tx_pps |
# |                 tx_drops |
# |                     None |
# +--------------------------+

# %%
spark.read \
    .format("iceberg") \
    .load("nyc.permits") \
    .groupBy("borough") \
    .count() \
    .show()

# %% [markdown]
# # Generate an ID for an Integrated Audit Session

# %% [markdown]
# An integrated audit session is a single cadence of:
# 1. Staging changes to a table
# 2. Auditing the staged changes
# 3. Committing the changes (optional)
#
# Each of these sessions must be represented with an ID. You can use any convention that makes sense in your environment but in this demo we'll simply use a UUID.

# %%
import uuid
ia_session_id = uuid.uuid4().hex
ia_session_id

# %% [markdown]
# # The Setup

# %% [markdown]
# Tables by default are not configured to allow integrated audits, therefore the first step is enabling this by setting the `write.wap.enabled` table metadata property to `true`

# %%
# %%sql
#
# ALTER TABLE nyc.permits
# SET TBLPROPERTIES (
#     'write.wap.enabled'='true'
# )

# %% [markdown]
# Next, the `spark.wap.id` property of your Spark session configuration must be set to the integrated audit session ID.

# %%
spark.conf.set('spark.wap.id', ia_session_id)

# %% [markdown]
# With a `spark.wap.id` value set, you can now safely write **directly to the permits table**--don't worry, these changes will only be staged, not committed!

# %% [markdown]
# # Staging The Changes

# %% [markdown]
# To stage the changes, you simply write directly to the `permits` table. This is awesome in situations where you're working with a large and complex data ingestion pipeline.
# Instead of including hard-coded logic in your pipeline to switch between a sort of "audit-mode" as opposed to "production-mode", with integrated audits you simple run your
# production code!
#
# For this demo, let's use a simple query that deletes all records for film permits in the manhattan borough.

# %%
# %%sql
#
# DELETE FROM nyc.permits
# WHERE borough='Manhattan'

# %% [markdown]
# As described, even though the query was executed against the production table, these changes are only staged and not committed since we are within an integrated audit session. Let's confirm this by verifying that a count by borough still includes the Manhattan records.

# %%
# %%sql
#
# SELECT borough, count(*) permit_cnt
# FROM nyc.permits
# GROUP BY borough

# %% [markdown]
# # The Audit

# %% [markdown]
# Once the changes for this session are staged, you can perform all of your audits to validate the data. The first step is to retrieve the snapshot ID generated by the changes and tagged with this integrated audit session ID.

# %%
query = f"""
SELECT snapshot_id
FROM nyc.permits.snapshots
WHERE summary['wap.id'] = '{ia_session_id}'
"""

ia_session_snapshot = spark.sql(query).head().snapshot_id

# %%
ia_session_snapshot

# %% [markdown]
# This snapshot includes the staged (but not commited) changes to your production table. Once you have this snapshot ID, you can use Iceberg's Time Travel feature to query it!

# %%
spark.read \
    .option("snapshot-id", ia_session_snapshot) \
    .format("iceberg") \
    .load("nyc.permits") \
    .groupBy("borough") \
    .count() \
    .show()

# %% [markdown]
# At this point, you can use any auditing tool or technique to validate your changes. For this demo, we'll do a simple audit that confirms that the only remaining boroughs are Queens, Brooklyn, Bronx, and Staten Island. If either borough is missing or any additional boroughs are found, we'll raise an exception.

# %%
expected_boroughs = {"Queens", "Brooklyn", "Bronx", "Staten Island"}
distinct_boroughs = spark.read \
    .option("snapshot-id", ia_session_snapshot) \
    .format("iceberg") \
    .load("nyc.permits") \
    .select("borough") \
    .distinct() \
    .toLocalIterator()
boroughs = {row[0] for row in distinct_boroughs}

# %%
# Since `boroughs` and `required_boroughs` are both sets (array of distinct items),
# we can confirm that they match by checking that the lengths of the sets are equal
# to eachother as well as to the union of both sets.
if len(boroughs) != len(expected_boroughs) != len(set.union(boroughs, expected_boroughs)):
    raise ValueError(f"Audit failed, borough set does not match expected boroughs: {boroughs} != {expected_boroughs}")

# %% [markdown]
# If the above check does not fail, we can go ahead and commit our staged data to publish our changes!

# %% [markdown]
# # The Publish

# %% [markdown]
# After the audits are completed, publishing the data is as simple as running a `cherrypick_snapshot` stored procedure.

# %%
publish_query = f"CALL system.cherrypick_snapshot('nyc.permits', {ia_session_snapshot})"
# %sql $publish_query

# %% [markdown]
# That's it! Publishing the changes from this integrated audit session is a simple metadata-only operation that instantly makes the changes live for all downstream consumers querying the `permits` table! Query results will now include the commit that removed all Manhattan records.

# %%
spark.read \
    .format("iceberg") \
    .load("nyc.permits") \
    .groupBy("borough") \
    .count() \
    .show()

# %% [markdown]
# # What Happens When The Audits Fail?

# %% [markdown]
# What about when your audits fail? What happens to the snapshots generated? How about the data and metadata files?
#
# One of the best parts of Iceberg's integrated audits is that the cleanup of "*staged-yet-not-committed-data*" is part of the normal snapshot cleanup process of a typical Iceberg warehouse. To be more specific, let's say a daily snapshot expiration is performed on the data warehouse (using the [expire_snapshots](https://iceberg.apache.org/docs/latest/spark-procedures/#expire_snapshots) procedure) and all snapshots older than 7 days are expired. That means once your staged snapshot reaches 7 days in age, it will be expired.
#
# Additionally, since the changes were never committed, the underlying data files for the snapshot will be removed since they're not referenced by any other snapshots in the linear history of the table.
#
# Let's see this in action. First, start a new integrated audit session and stage a commit by inserting a single record.

# %%
ia_session_id = uuid.uuid4().hex
ia_session_id

# %%
spark.conf.set('spark.wap.id', ia_session_id)

# %%
# %%sql
#
# INSERT INTO nyc.permits
# VALUES (
#     'Hoboken',
#     'Television',
#     '1',
#     'United States of America',
#     '2021-11-24T23:00:00.000',
#     '2021-11-23T09:38:17.000',
#     'Mayor\'s Office of Film, Theatre & Broadcasting',
#     '613322',
#     'Shooting Permit',
#     'WASHINGTON STREET',
#     '100',
#     '2021-11-24T07:00:00.000',
#     'Episodic series',
#     '07030'
# )

# %% [markdown]
# Next, let's identify the snapshot that was tagged with the integrated audit session ID.

# %%
# %%sql
#
# SELECT snapshot_id
# FROM nyc.permits.snapshots

# %%
query = f"""
SELECT snapshot_id
FROM nyc.permits.snapshots
WHERE summary['wap.id'] = '{ia_session_id}'
"""

ia_session_snapshot = spark.sql(query).head().snapshot_id

# %%
ia_session_snapshot

# %% [markdown]
# A quick check of the history table shows that this snapshot is not included as part of the current history of the table since it has not been published yet.

# %%
# %%sql
#
# SELECT *
# FROM nyc.permits.history

# %% [markdown]
# In a scenario where the audits fail and this change is not published, the `expire_snapshots` procedure will clean up the snapshot **and** the data files. Let's demonstrate this by calling the `expire_snapshots` procedure for all snapshots older than the current timestamp.

# %%
import time
# %sql CALL system.expire_snapshots('nyc.permits', {round(time.time() * 1000)}, 100)

# %% [markdown]
# The output from the `expire_snapshots` procedure shows that a data file, a manifest file, and a manifest list file were deleted. Furthermore, the snapshot no longer appears in the permit table's snapshots table.

# %%
# %%sql
#
# SELECT *
# FROM nyc.permits.snapshots
